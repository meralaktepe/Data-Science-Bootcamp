# %% [markdown]
# <a href="https://www.kaggle.com/code/merall/data-science-bootcamp-prj-01?scriptVersionId=194131643" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# Python Programming for Data Science
# Data Structures, Functions, Conditions & Loops, Comprehensions

# %%
###############################################
# GÖREV 1: Veri yapılarının tipleriniz inceleyiniz.
###############################################

# İnt tipinde değişkendir
x = 8
type(x)

# Float tipinde değişkendir
y = 3.2
type(y)

# Complex tipinde değişkendir
z = 8j + 18
type(z)

# String tipinde değişkendir
a = "Hello World"
type(a)

# Bool tipinde değişkendir
b = True
type(b)

# Bool tipinde değişkendir
c = 23 < 22
type(c)

# liste tipinde değişkendir
l = [1, 2, 3, 4, "String", 3.2, False]
type(l)

# Sözlük tipinde değişkendir
d = {"Name": "Jake",
     "Age": [27, 56],
     "Adress": "Downtown"}
type(d)

# Tuple tipinde değişkendir
t = ("Machine Learning", "Data Science")
type(t)

# Set tipinde değişkendir
s = {"Python", "Machine Learning", "Data Science", "Python"}
type(s)
# Out:
# set

# %%
###############################################
# GÖREV 2: Verilen string ifadenin tüm harflerini büyük harfe çeviriniz. Virgül ve nokta yerine space koyunuz, kelime kelime ayırınız.
###############################################

text = "The goal is to turn data into information, and information into insight."
text = text.upper().replace(",", " ").replace(".", " ")
words = text.split()
print(words)
# Out:
# ['THE', 'GOAL', 'IS', 'TO', 'TURN', 'DATA', 'INTO', 'INFORMATION', 'AND', 'INFORMATION', 'INTO', 'INSIGHT']

# %%
###############################################
# GÖREV 3: Verilen liste için aşağıdaki görevleri yapınız.
###############################################

lst = ["D", "A", "T", "A", "S", "C", "I", "E", "N", "C", "E"]

# Adım 1: Verilen listenin eleman sayısına bakın.
len(lst)

# Adım 2: Sıfırıncı ve onuncu index'teki elemanları çağırın.
lst[0], lst[10]

# Adım 3: Verilen liste üzerinden ["D","A","T","A"] listesi oluşturun.
lst[0:4]

# Adım 4: Sekizinci index'teki elemanı silin.
lst.pop(8)
lst

# Adım 5: Yeni bir eleman ekleyin.
lst.append("K")
lst

# Adım 6: Sekizinci index'e  "N" elemanını tekrar ekleyin.
lst.insert(8,"N")
lst
# Out:
# ['D', 'A', 'T', 'A', 'S', 'C', 'I', 'E', 'N', 'C', 'E', 'K']

# %%
###############################################
# GÖREV 4: Verilen sözlük yapısına aşağıdaki adımları uygulayınız.
###############################################

dict = {'Christian': ["America", 18],
        'Daisy': ["England", 12],
        'Antonio': ["Spain", 22],
        'Dante': ["Italy", 25]}

# Adım 1: Key değerlerine erişiniz.
dict.keys()

# Adım 2: Value'lara erişiniz.
dict.values()

# Adım 3: Daisy key'ine ait 12 değerini 13 olarak güncelleyiniz.
dict["Daisy"][1] = 13
dict

# Adım 4: Key değeri Ahmet value değeri [Turkey,24] olan yeni bir değer ekleyiniz.
dict.update({"Ahmet" : ["Turkey",24]})
dict

# Adım 5: Antonio'yu dictionary'den siliniz.
dict.pop("Antonio")
dict
# Out:
# {'Christian': ['America', 18],
#  'Daisy': ['England', 13],
#  'Dante': ['Italy', 25],
#  'Ahmet': ['Turkey', 24]}

# %%
###############################################
# GÖREV 5: Arguman olarak bir liste alan, listenin içerisindeki tek ve çift sayıları ayrı listelere atıyan ve bu listeleri return eden fonskiyon yazınız.
###############################################

l = [2, 13, 18, 93, 22]

# 1. Yöntem

def listCreate(lst):
    evenList = []
    oddList = []

    for i in lst:
        if i % 2 == 0:
            evenList.append(i)
        else:
            oddList.append(i)
    return evenList, oddList

print(listCreate(l))

# 2. Yöntem

evenList = []
oddList = []

[evenList.append(i) if i % 2 == 0 else oddList.append(i) for i in l]
print(evenList, oddList)
# Out:
# ([2, 18, 22], [13, 93])
# [2, 18, 22] [13, 93]

# %%
###############################################
# GÖREV 6: Aşağıda verilen listede mühendislik ve tıp fakülterinde dereceye giren öğrencilerin isimleri bulunmaktadır.
# Sırasıyla ilk üç öğrenci mühendislik fakültesinin başarı sırasını temsil ederken son üç öğrenci de tıp fakültesi öğrenci sırasına aittir.
# Enumarate kullanarak öğrenci derecelerini fakülte özelinde yazdırınız.
###############################################

ogrenciler = ["Ali", "Veli", "Ayşe", "Talat", "Zeynep", "Ece"]
tip_fakulte = []
muhendislik_fakulte = []

for index, ogrenci in enumerate(ogrenciler):
    if index < 3:
        muhendislik_fakulte.append(ogrenci)
    else:
        tip_fakulte.append(ogrenci)

for i in range(3):
    print(str(i+1) + " " + muhendislik_fakulte[i] + " " + "Mühendislik Fakültesi")

for i in range(3):
    print(str(i+1) + " " + tip_fakulte[i] + " " + "Tıp Fakültesi")
# Out:
# 1 Ali Mühendislik Fakültesi
# 2 Veli Mühendislik Fakültesi
# 3 Ayşe Mühendislik Fakültesi
# 1 Talat Tıp Fakültesi
# 2 Zeynep Tıp Fakültesi
# 3 Ece Tıp Fakültesi

# %%
###############################################
# GÖREV 7: Aşağıda 3 adet liste verilmiştir. Listelerde sırası ile bir dersin kodu, kredisi ve kontenjan bilgileri yer almaktadır. Zip kullanarak ders bilgilerini bastırınız.
###############################################

ders_kodu = ["CMP1005", "PSY1001", "HUK1005", "SEN2204"]
kredi = [3, 4, 2, 4]
kontenjan = [30, 75, 150, 25]

ders_bilgileri = list(zip(ders_kodu, kredi, kontenjan))

for i in ders_bilgileri:
    print("Ders Kodu: ", i[0], "  ", "Kredi: ", i[1], "  ", "Kontenjan: ", i[2])
# Out:
# Ders Kodu:  CMP1005    Kredi:  3    Kontenjan:  30
# Ders Kodu:  PSY1001    Kredi:  4    Kontenjan:  75
# Ders Kodu:  HUK1005    Kredi:  2    Kontenjan:  150
# Ders Kodu:  SEN2204    Kredi:  4    Kontenjan:  25

# %%
###############################################
# GÖREV 8: Aşağıda 2 adet set verilmiştir.
# Sizden istenilen eğer 1. küme 2. kümeyi kapsiyor ise ortak elemanlarını eğer kapsamıyor ise 2. kümenin 1. kümeden farkını yazdıracak fonksiyonu tanımlamanız beklenmektedir.
###############################################

kume1 = set(["data", "python"])
kume2 = set(["data", "function", "qcut", "lambda", "python", "miuul"])


def kumeler(kume1, kume2):
    if kume1.issuperset(kume2):
        print(kume1.intersection(kume2))
    else:
        print(kume2.symmetric_difference(kume1))

kumeler(kume1, kume2)
# Out:
# {'miuul', 'qcut', 'function', 'lambda'}

# %%
# ###############################################
# # GÖREV 1: List Comprehension yapısı kullanarak car_crashes verisindeki numeric değişkenlerin isimlerini büyük harfe çeviriniz ve başına NUM ekleyiniz.
# ###############################################
#
# # Beklenen Çıktı
#
# # ['NUM_TOTAL',
# #  'NUM_SPEEDING',
# #  'NUM_ALCOHOL',
# #  'NUM_NOT_DISTRACTED',
# #  'NUM_NO_PREVIOUS',
# #  'NUM_INS_PREMIUM',
# #  'NUM_INS_LOSSES',
# #  'ABBREV']
#
# # Notlar:
# # Numerik olmayanların da isimleri büyümeli.
# # Tek bir list comp yapısı ile yapılmalı.


import seaborn as sns
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.width', 500)

df = sns.load_dataset("car_crashes")
df.columns
df.info()

tempColumns = ["NUM_" + col.upper() if df[col].dtype != "O" else col.upper() for col in df.columns]
df.columns = tempColumns
print(df.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total           51 non-null     float64
#  1   speeding        51 non-null     float64
#  2   alcohol         51 non-null     float64
#  3   not_distracted  51 non-null     float64
#  4   no_previous     51 non-null     float64
#  5   ins_premium     51 non-null     float64
#  6   ins_losses      51 non-null     float64
#  7   abbrev          51 non-null     object
# dtypes: float64(7), object(1)
# memory usage: 3.3+ KB
# Index(['NUM_TOTAL', 'NUM_SPEEDING', 'NUM_ALCOHOL', 'NUM_NOT_DISTRACTED', 'NUM_NO_PREVIOUS', 'NUM_INS_PREMIUM', 'NUM_INS_LOSSES', 'ABBREV'], dtype='object')

# %%
# ###############################################
# # GÖREV 2: List Comprehension yapısı kullanarak car_crashes verisindeki isminde "no" barındırmayan değişkenlerin isimlerininin sonuna "FLAG" yazınız.
# ###############################################
#
# # Notlar:
# # Tüm değişken isimleri büyük olmalı.
# # Tek bir list comp ile yapılmalı.
#
# # Beklenen çıktı:
#
# # ['TOTAL_FLAG',
# #  'SPEEDING_FLAG',
# #  'ALCOHOL_FLAG',
# #  'NOT_DISTRACTED',
# #  'NO_PREVIOUS',
# #  'INS_PREMIUM_FLAG',
# #  'INS_LOSSES_FLAG',
# #  'ABBREV_FLAG']

tempColumns = [col.upper() + "_FLAG" if "no" not in col else col.upper() for col in df.columns]
print(tempColumns)
# Out:
# ['NUM_TOTAL_FLAG', 'NUM_SPEEDING_FLAG', 'NUM_ALCOHOL_FLAG', 'NUM_NOT_DISTRACTED_FLAG', 'NUM_NO_PREVIOUS_FLAG', 'NUM_INS_PREMIUM_FLAG', 'NUM_INS_LOSSES_FLAG', 'ABBREV_FLAG']

# %%
# ###############################################
# # Görev 3: List Comprehension yapısı kullanarak aşağıda verilen değişken isimlerinden FARKLI olan değişkenlerin isimlerini seçiniz ve yeni bir dataframe oluşturunuz.
# ###############################################

import seaborn as sns
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.width', 500)

df = sns.load_dataset("car_crashes")

og_list = ["abbrev", "no_previous"]

# # Notlar:
# # Önce yukarıdaki listeye göre list comprehension kullanarak new_cols adında yeni liste oluşturunuz.
# # Sonra df[new_cols] ile bu değişkenleri seçerek yeni bir df oluşturunuz adını new_df olarak isimlendiriniz.
#
# # Beklenen çıktı:
#
# #    total  speeding  alcohol  not_distracted  ins_premium  ins_losses
# # 0 18.800     7.332    5.640          18.048      784.550     145.080
# # 1 18.100     7.421    4.525          16.290     1053.480     133.930
# # 2 18.600     6.510    5.208          15.624      899.470     110.350
# # 3 22.400     4.032    5.824          21.056      827.340     142.390
# # 4 12.000     4.200    3.360          10.920      878.410     165.630
#
new_cols = [col for col in df.columns if og_list.count(col) == 0]
print(new_cols)

new_df = df[new_cols]
print(new_df)
# Out:
# ['total', 'speeding', 'alcohol', 'not_distracted', 'ins_premium', 'ins_losses']
#     total  speeding  alcohol  not_distracted  ins_premium  ins_losses
# 0    18.8     7.332    5.640          18.048       784.55      145.08
# 1    18.1     7.421    4.525          16.290      1053.48      133.93
# 2    18.6     6.510    5.208          15.624       899.47      110.35
# 3    22.4     4.032    5.824          21.056       827.34      142.39
# 4    12.0     4.200    3.360          10.920       878.41      165.63
# 5    13.6     5.032    3.808          10.744       835.50      139.91
# 6    10.8     4.968    3.888           9.396      1068.73      167.02
# 7    16.2     6.156    4.860          14.094      1137.87      151.48
# 8     5.9     2.006    1.593           5.900      1273.89      136.05
# 9    17.9     3.759    5.191          16.468      1160.13      144.18
# 10   15.6     2.964    3.900          14.820       913.15      142.80
# ...
